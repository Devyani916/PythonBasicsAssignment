# %% [markdown]
# <a href="https://colab.research.google.com/github/Devyani916/PythonBasicsAssignment/blob/main/DataToolkitAssignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Toolkit Assignment**

# %% [markdown]
# ***Theoretical Questions:***

# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python?
# - NumPy is a Python library that supports large multi-dimensional arrays and mathematical operations.
# - Efficient: NumPy is optimized for fast numeric computation. It's built in part with C and C++, which allows it to run faster than Python's built-in lists.
# - Versatile: NumPy supports a wide range of mathematical functions, including linear algebra, random number generation, and Fourier transforms.
# - Open source: NumPy is free and open source, and its source code is available on GitHub.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 2. How does broadcasting work in Python?
# - Broadcasting helps to perform mathematical operation on arrays with different shapes.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 3. What is a Pandas DataFrame?
# - DataFrame in Pandas is a two dimensional data structure which is a tabular data. It can be seen as a table and organized in rows and columns.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 4. Explain the use of the groupby() method in Pandas?
# - In Pandas, groupby() method is used to split the data into groups based on predefined criteria, along rows (by default, axis=0 ), or columns ( axis=1 ).

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 5. Why is Seaborn preferred for statistical visualizations?
# - Seaborn can be used for data visualization. It is preferred for statistical visualization as it transform more complex datasets into a clear visual representations making it easier to understand, which helps to understand trends and  relationship within data.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 6. What are the differences between NumPy arrays and Python lists?
# - Python lists can store elements of different data types and are more flexible for manipulation, while NumPy arrays are optimized for numerical computations and require all elements to be of the same data type, making them significantly faster for large datasets and mathematical operations.
# -Essentially, lists are more versatile for general data storage, while NumPy arrays are designed for high-performance numerical calculations.
# -Use a Python list:
# When you need to store a collection of diverse data types, or when frequent modifications to the data are required.
# -Use a NumPy array:
# When performing heavy numerical computations on large datasets, especially when dealing with matrices or multi-dimensional data.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 7. What is a heatmap, and when should it be used?
# - A heatmap is a visual representation of data which uses colors to show the values or densities to identify the patterns, correlation, and variation in data.
# - Heatmap uses to understand the behaviour of user, to improve products, to access marketing trends as well as to monitor productions, etc.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 8. What does the term "vectorized operation" mean in NumPy?
# - Vectorized operation in NumPy is nothing but the iterative approach which performs mathematical operation on entire array without explicit use of any loops.
# - Vectorization helps to improve simplicity and optimized the code which directly improve the performance and scalability of the code.
# - Vectorized operation preffered in case of machine learning, and data analysis.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 9. How does Matplotlib differ from Plotly?
# - Matplotlib and Plotly are Python libraries used for data visualization. Matplotlib is a popular library that is great for creating static visualizations, while Plotly is a more sophisticated tool suited for creating elaborate plots more efficiently.
# - Matplotlib is more explicit in declaring each plot element, making it an ideal place for new Python users to start, while Plotly is well-suited for creating interactive plot.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 10. What is the significance of hierarchical indexing in Pandas?
# - Hierarchical Indexing is also known as MultiIndexing in Pandas that allows you to have multiple levels of indexing on an axis. This capability is particularly useful when dealing with high-dimensional data.
# - Hierarchical Indexing can help you to easily group, slice, and aggregate your data, making your analysis more efficient and intuitive.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 11. What is the role of Seaborn's pairplot() function?
# - Seaborn's pairplot() is a function used to visualize the relationship between all the numeric variables in dataset.
# - pairplot() function grid of scatter plot where each cell represent the relationship between two variables.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 12. What is the purpose of the describe() function in Pandas?
# - The describe() function  in pandas summarizes a DataFrame's columns by providing statistical information.
# - By default, describe() function returns the count, mean, standard deviation, 25th percentile, median (i.e. 50 percentile) , 75th percentile and maximum of the columns.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 13. Why is handling missing data important in Pandas?
# - Handling missing data is important in Pandas as it might gives inaccurative analysis results, which leads to erroneous insights and leading to poor decision making.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 14. What are the benefits of using Plotly for data visualization?
# - Plotly gives us the interactive and customizable charts easily. Its interactive feature includes zoom, hover, enhance data exploration as well as we can share this plot online and download it.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 15. How does NumPy handle multidimesional arrays?
# - In NumPy for data in any dimensional array stored in memory as a long 1D array. It can reshape() array. It helps to perform different mahematical operations on an array.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 16. What is the role of Bokeh in data visualization?
# - Bokeh is a Python library primarily used to create interactive data visualizations for modern web browsers, allowing users to build dynamic and visually appealing graphics, particularly suited for dashboards and applications where large datasets need to be explored with interactive features like hovering, zooming, and filtering; essentially, it enables users to interact with their data in real-time through visual representations.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 17. Explain the difference between apply() and map() in Pandas?
# - The map() function is great for simple, element-wise transformations on a Series. Whereas, the apply() is more versatile, working on both Series & DataFrames. When dealing with multiple columns or row-wise operations, always go with apply().

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 18. What are some advanced features of NumPy?
# - NumPy is a Python library that offers many advanced features for numerical computing. Some of the features of NumPy are:
#    1.   Broadcasting: Automatically aligns arrays of different shapes for element-wise computations
#    2. Linear algebra: Includes routines for matrix multiplication, decompositions, and determinants
#    3. Vectorization: Applies operations directly on entire arrays, eliminating the need for explicit Python loops
#    4. Random number generation: Generates large arrays of samples all at once

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 19. How does Pandas simplify time series analysis?
# - Pandas provides a Timestamp object. The library then makes a DatetimeIndex from these Timestamp objects to index a DataFrame or Series.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 20. What is the role of a pivot table in Pandas?
# - It allows us to restructure a DataFrame by turning rows into columns and columns into rows based on a specified index column, a specified values column. This creates a summary table of the data that is easy to read and analyze.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 21. Why is NumPy's array slicing faster than Python's list slicing?
# - NumPy arrays are optimized for numerical computations, with efficient element-wise operations and mathematical functions. These operations are implemented in C, resulting in faster performance than equivalent operations on lists. As C is one of the fastest programming language.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 22. What are some common use cases of Seaborn?
# - Python Seaborn library is a widely popular data visualization library that is commonly used for data science and machine learning tasks. We can built the matplotlib data visualization library and can perform exploratory analysis. We can create interactive plots to answer questions about data.

# %% [markdown]
# ________________________________________________________________________________
# ________________________________________________________________________________

# %% [markdown]
# ***Practical Questions***

# %% [markdown]
# 1. How do you create a 2D NumPy array and calculate the sum of each row?

# %%
import numpy as np #importing numpy library and alias np of numpy

A = np.array([[1,2,3], [3,4,5], [6,7,8]]) #Creation of 2D array using Numpy
print(f"Sum of each row :{np.sum(A, axis=1)}") # Calculate the sum of array A row wise
# Out:
# Sum of each row:[ 6 12 21]

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 2. Write a Pandas script to find the mean of a specific column in a DataFrame.

# %%
import pandas as pd #importing pandas library and alias pd of pandas

df = pd.DataFrame({'Name': ['Devyani', 'Saikat', 'Pratik', 'Prashil'], 'Age':[28,27,26,26]})
df
# Out:
#       Name  Age
# 0  Devyani   28
# 1   Saikat   27
# 2   Pratik   26
# 3  Prashil   26

# %%
df['Age'].mean(axis = 0) #Calculate the mean of Age
# Out:
# 26.75

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 3. Create a scatter plot using Matplotlib.

# %%
import matplotlib.pyplot as plt #importing matplotlib library and alias plt of matplotlib

df = pd.DataFrame({'Name': ['Devyani', 'Saikat', 'Pratik', 'Prashil'], 'Age':[28,27,26,26]})

plt.scatter(df['Name'], df['Age']) #Scatter plot using matplotlib
plt.xlabel('Name')
plt.ylabel('Age')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 4. How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?

# %%
import seaborn as sns #importing seaborn library and alias sns of seaborn
import matplotlib.pyplot as plt

df = pd.DataFrame({'EmpId': ['001', '002', '003', '004'], 'Age':[28,27,26,26], 'Salary' : [50000, 66000, 55000, 70000]})
df
# Out:
#   EmpId  Age  Salary
# 0   001   28   50000
# 1   002   27   66000
# 2   003   26   55000
# 3   004   26   70000

# %%
sns.heatmap(df.corr()) #Calculate the correlation matrix using Seaborn
plt.show()

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 5. Generate a bar plot using a Plotly.

# %%
import plotly.express as px #importing plotly library and alias px of plotly
import plotly.graph_objects as go

df = pd.DataFrame({'EmpId': ['001', '002', '003', '004'], 'Age':[28,20,23, 22], 'Salary': [100000, 200000, 150000, 190000]})
df
# Out:
#   EmpId  Age  Salary
# 0   001   28  100000
# 1   002   20  200000
# 2   003   23  150000
# 3   004   22  190000

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x = df['EmpId'], y = df['Salary']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 6. Create a DataFrame and add a new column based on an existing column.

# %%
df = pd.DataFrame({'EmpId': ['001', '002', '003', '004'], 'Age':[28,26,24,25], 'Salary': [10000,20000,40000,58899]})
df
# Out:
#   EmpId  Age  Salary
# 0   001   28   10000
# 1   002   26   20000
# 2   003   24   40000
# 3   004   25   58899

# %%
df['Salary_morethan_avgSal'] = df['Salary'].mean(axis = 0) < df['Salary']  #add new column i.e. Salary_morethan_avgSal based on Salary column
df
# Out:
#   EmpId  Age  Salary  Salary_morethan_avgSal
# 0   001   28   10000                   False
# 1   002   26   20000                   False
# 2   003   24   40000                    True
# 3   004   25   58899                    True

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 7. Write a program to perform element-wise multiplication of two NumPy arrays.

# %%
import numpy as np

arr1 = np.array([[1,2,4], [2,4,5], [5,6,8]])
arr2 = np.array([[5,7,8],[8,2,1], [10,7,9]])
print(f"{arr1}\n\n{arr2}")
print(f"\n\nElementwise multiplication of two NumPy arrays:\n{arr1*arr2}") #Element wise multiplication
# Out:
# [[1 2 4]
#  [2 4 5]
#  [5 6 8]]
#
# [[ 5  7  8]
#  [ 8  2  1]
#  [10  7  9]]
#
#
# Elementwise multiplication of two NumPy arrays:
# [[ 5 14 32]
#  [16  8  5]
#  [50 42 72]]

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 8. Create a line plot with multiple lines using Matplotlib.

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = [1,2,3,4,5]
y = [3,2,2,2,1]

# plot lines
plt.plot(x, y, label = "line 1")
plt.plot(y, x, label = "line 2")
plt.plot(x, np.sin(x), label = "line 3")
plt.plot(x, np.cos(x), label = "line 4")
plt.legend()
plt.title("Line Plot")
plt.xlabel("x-Axis")
plt.ylabel("y-Axis")
plt.show()

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold.

# %%
import pandas as pd

df = pd.DataFrame({"Name":['Devu','Bob', 'Alice', 'Sai'], "Designation":["AM", "TL","Agent", "Manager"], "Salary": [100000, 40000, 21000, 200000] })
df
# Out:
#     Name Designation  Salary
# 0   Devu          AM  100000
# 1    Bob          TL   40000
# 2  Alice       Agent   21000
# 3    Sai     Manager  200000

# %%
df[df['Salary'] > 90000]
# Out:
#    Name Designation  Salary
# 0  Devu          AM  100000
# 3   Sai     Manager  200000

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 10. Create a histogram using Seaborn to visualize a distribution.

# %%
import seaborn as sns

df = pd.DataFrame({"Name":['Devu','Bob', 'Alice', 'Sai', 'Pratik'], "Designation":["AM", "TL","Agent", "Manager", 'SM'], "Salary": [100000, 40000, 21000, 200000, 150000], "Gender": ["Female", "Male", "Female", "Male", "Male"] })
sns.histplot(df['Gender'], color = 'blue')
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 11. Perform matrix multiplication using NumPy.

# %%
import numpy as np

mat1 = np.random.randint(1,5, size= (3,3))
mat2 = np.random.randint(1,5, size= (3,3))
print(f"{mat1}\n\n{mat2}")
print(f"\n\nMatrix multiplication:\n{mat1@mat2}")
# Out:
# [[2 4 2]
#  [3 4 4]
#  [2 1 3]]
#
# [[2 4 2]
#  [4 2 3]
#  [2 2 3]]
#
#
# Matrix multiplication:
# [[24 20 22]
#  [30 28 30]
#  [14 16 16]]

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 12. Use Pandas to load a CSV file and display its first 5 rows.

# %%
import pandas as pd

file = pd.read_csv("https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2023-financial-year-provisional/Download-data/annual-enterprise-survey-2023-financial-year-provisional.csv")

# %%
file.head(5) #print first 5 rows of data
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# 13. Create a 3D scatter plot using Plotly.

# %%
import plotly.graph_objects as go
import plotly.express as px

fig = go.Figure()
fig.add_trace(go.Scatter3d(x=[1, 3,4,5], y=[2,5,6,8], z=[6,2,5,1]))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ****************************************************************************************************************************************************************
